# %%
# !git clone https://github.com/GoHakNeung/PAAinJN.git
# %run /content/PAAinJN/code_check.py

# %%
Question(question_8601)
# Out:
#  <h2 style = "background-color:yellow; ">Description</h2>
# <p>Let's create a data frame for the df variable by entering </p>
# <p>30, 34, 21, 22, 54, 23, 43 in the Apples column and 21, 12, 43, 23, 33, 56, 23 in the Bananas column.</p>
# <HR>
# <div style = "float:left;width:50%">
# <h2> example </h2>
# <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Apples</th>
#       <th>Bananas</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>30</td>
#       <td>21</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>34</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>21</td>
#       <td>43</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>22</td>
#       <td>23</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>54</td>
#       <td>33</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>23</td>
#       <td>56</td>
#     </tr>
# ...

# %%
Question(question_8602)
# Out:
#  <h2 style = "background-color:yellow; ">Description</h2>
# <p>Let's import the checkup.csv file in the csv_file folder into a data frame in the df variable.</p>
# <h3 = "white-space: pre-wrap;">data=pd.read_csv("/content/PAAinJN/csv_file/checkup.csv")</h3>
# <HR>
# <div style = "float:left;width:50%">
# <h2> example </h2>
# <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>나이</th>
#       <th>성별</th>
#       <th>키(cm)</th>
#       <th>몸무게(kg)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>6세</td>
#       <td>남</td>
#       <td>120.5</td>
#       <td>24.2</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>6세</td>
#       <td>여</td>
#       <td>119.3</td>
#       <td>22.9</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>7세</td>
#       <td>남</td>
#       <td>125.7</td>
#       <td>27.1</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>7세</td>
# ...

# %%
Question(question_8603)
# Out:
#  <h2 style = "background-color:yellow; ">Description</h2>
# <h3 = "white-space: pre-wrap;">data=pd.read_csv("/content/PAAinJN/csv_file/bike_seoul.csv")</h3>
# <p>Let's just import the head() value of the bike_seoul.csv in the csv_file folder into the df variable.</p>
# <HR>
# <div style = "float:left;width:50%">
# <h2> Data before preprocessing </h2>
# <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>day</th>
#       <th>rent</th>
#       <th>humidity</th>
#       <th>temperature</th>
#       <th>dust</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2022-01-01</td>
#       <td>29185</td>
#       <td>46.3</td>
#       <td>-4.3</td>
#       <td>34</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2022-01-02</td>
#       <td>28914</td>
#       <td>57.9</td>
#       <td>-1.3</td>
#       <td>42</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2022-01-03</td>
# ...

# %%
Question(question_8604)
# Out:
#  <h2 style = "background-color:yellow; ">Description</h2>
# <h3 = "white-space: pre-wrap;">data=pd.read_csv("/content/PAAinJN/csv_file/bike_seoul.csv")</h3>
# <p>Let's just import the tail() value of the bike_seoul.csv in the csv_file folder in the df variable.</p>
# <HR>
# <div style = "float:left;width:50%">
# <h2> Data before preprocessing </h2>
# <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>day</th>
#       <th>rent</th>
#       <th>humidity</th>
#       <th>temperature</th>
#       <th>dust</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2022-01-01</td>
#       <td>29185</td>
#       <td>46.3</td>
#       <td>-4.3</td>
#       <td>34</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2022-01-02</td>
#       <td>28914</td>
#       <td>57.9</td>
#       <td>-1.3</td>
#       <td>42</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2022-01-03</td>
# ...

# %%
Question(question_8605)
# Out:
#  <h2 style = "background-color:yellow; ">Description</h2>
# <h3 = "white-space: pre-wrap;">data=pd.read_csv("/content/PAAinJN/csv_file/bike_seoul.csv")</h3>
# <p>Let's just import the describ() value of the bike_seoul.csv in the csv_file folder in the df variable.</p>
# <HR>
# <div style = "float:left;width:50%">
# <h2> Data before preprocessing </h2>
# <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>day</th>
#       <th>rent</th>
#       <th>humidity</th>
#       <th>temperature</th>
#       <th>dust</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2022-01-01</td>
#       <td>29185</td>
#       <td>46.3</td>
#       <td>-4.3</td>
#       <td>34</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2022-01-02</td>
#       <td>28914</td>
#       <td>57.9</td>
#       <td>-1.3</td>
#       <td>42</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2022-01-03</td>
# ...

# %%
Question(question_8606)
# Out:
#  <h2 style = "background-color:yellow; ">Description</h2>
# <h3 = "white-space: pre-wrap;">data=pd.read_csv("/content/PAAinJN/csv_file/bike_seoul.csv")</h3>
# <p>Let's import bike_seoul.csv in the csv_file folder into df by arranging the rent columns in descending order.</p>
# <HR>
# <div style = "float:left;width:50%">
# <h2> Data before preprocessing </h2>
# <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>day</th>
#       <th>rent</th>
#       <th>humidity</th>
#       <th>temperature</th>
#       <th>dust</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2022-01-01</td>
#       <td>29185</td>
#       <td>46.3</td>
#       <td>-4.3</td>
#       <td>34</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2022-01-02</td>
#       <td>28914</td>
#       <td>57.9</td>
#       <td>-1.3</td>
#       <td>42</td>
#     </tr>
#     <tr>
#       <th>2</th>
# ...

# %%
Question(question_8607)
# Out:
#  <h2 style = "background-color:yellow; ">Description</h2>
# <h3 = "white-space: pre-wrap;">data=pd.read_csv("/content/PAAinJN/csv_file/total_checkup.csv")</h3>
# <p>Let's group by '학년' in the total_check.csv file in csv file to get the minimum value and save it in df.</p>
# <HR>
# <div style = "float:left;width:50%">
# <h2> Data before preprocessing </h2>
# <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>도시구분</th>
#       <th>시도</th>
#       <th>학교급</th>
#       <th>학년</th>
#       <th>성별</th>
#       <th>키</th>
#       <th>몸무게</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>도시</td>
#       <td>충북</td>
#       <td>초</td>
#       <td>초1</td>
#       <td>남</td>
#       <td>121.00000</td>
#       <td>24.200001</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>도시</td>
#       <td>대전</td>
#       <td>초</td>
#       <td>초1</td>
#       <td>남</td>
#       <td>126.00000</td>
# ...

# %%
Question(question_8608)
# Out:
#  <h2 style = "background-color:yellow; ">Description</h2>
# <h3 = "white-space: pre-wrap;">data=pd.read_csv("/content/PAAinJN/csv_file/total_checkup.csv")</h3>
# <p>Let's group by '학년' in the total_check.csv file in csv file to get the maxium value and save it in df.</p>
# <HR>
# <div style = "float:left;width:50%">
# <h2> Data before preprocessing </h2>
# <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>도시구분</th>
#       <th>시도</th>
#       <th>학교급</th>
#       <th>학년</th>
#       <th>성별</th>
#       <th>키</th>
#       <th>몸무게</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>도시</td>
#       <td>충북</td>
#       <td>초</td>
#       <td>초1</td>
#       <td>남</td>
#       <td>121.00000</td>
#       <td>24.200001</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>도시</td>
#       <td>대전</td>
#       <td>초</td>
#       <td>초1</td>
#       <td>남</td>
#       <td>126.00000</td>
# ...

# %%
Question(question_8609)
# Out:
#  <h2 style = "background-color:yellow; ">Description</h2>
# <h3 = "white-space: pre-wrap;">data=pd.read_csv("/content/PAAinJN/csv_file/total_checkup.csv")</h3>
# <p>Let's group by '시도' in the total_check.csv file in csv file to get the mean value of '키', '몸무게' and save it in df.</p>
# <HR>
# <div style = "float:left;width:50%">
# <h2> Data before preprocessing </h2>
# <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>도시구분</th>
#       <th>시도</th>
#       <th>학교급</th>
#       <th>학년</th>
#       <th>성별</th>
#       <th>키</th>
#       <th>몸무게</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>도시</td>
#       <td>충북</td>
#       <td>초</td>
#       <td>초1</td>
#       <td>남</td>
#       <td>121.00000</td>
#       <td>24.200001</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>도시</td>
#       <td>대전</td>
#       <td>초</td>
#       <td>초1</td>
#       <td>남</td>
# ...

# %%
Question(question_8610)
# Out:
#  <h2 style = "background-color:yellow; ">Description</h2>
# <h3 = "white-space: pre-wrap;">data=pd.read_csv("/content/PAAinJN/csv_file/movie_audience.csv")</h3>
# <p>Let's save only 'movie' and 'audience' in the movie_audience.csv file in df.</p>
# <HR>
# <div style = "float:left;width:50%">
# <h2> Data before preprocessing </h2>
# <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>rank</th>
#       <th>movie</th>
#       <th>...</th>
#       <th>sales_per_showing</th>
#       <th>audience_per_showing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>명량</td>
#       <td>...</td>
#       <td>719342.6386</td>
#       <td>93.341241</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>극한직업</td>
#       <td>...</td>
#       <td>476943.2974</td>
#       <td>55.551693</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
# ...

# %%
Question(question_8611)
# Out:
#  <h2 style = "background-color:yellow; ">Description</h2>
# <h3 = "white-space: pre-wrap;">data=pd.read_csv("/content/PAAinJN/csv_file/bike_seoul.csv")</h3>
# <p>Let's save the value in the csv file except for the day column in the bike_seoul.csv file in df.</p>
# <HR>
# <div style = "float:left;width:50%">
# <h2> Data before preprocessing </h2>
# <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>day</th>
#       <th>rent</th>
#       <th>humidity</th>
#       <th>temperature</th>
#       <th>dust</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2022-01-01</td>
#       <td>29185</td>
#       <td>46.3</td>
#       <td>-4.3</td>
#       <td>34</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2022-01-02</td>
#       <td>28914</td>
#       <td>57.9</td>
#       <td>-1.3</td>
#       <td>42</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2022-01-03</td>
# ...

# %%
Question(question_8612)
# Out:
#  <h2 style = "background-color:yellow; ">Description</h2>
# <h3 = "white-space: pre-wrap;">data=pd.read_csv("/content/PAAinJN/csv_file/bike_seoul.csv")</h3>
# <p>1. Excludes column 'day'.</p>
# <p>2. Each value is converted to a value between 0 and 1 and stored in the resultant df.</p>
# <p>(value - min) / (max - min)</p>
# <HR>
# <div style = "float:left;width:50%">
# <h2> Data before preprocessing </h2>
# <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>day</th>
#       <th>rent</th>
#       <th>humidity</th>
#       <th>temperature</th>
#       <th>dust</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2022-01-01</td>
#       <td>29185</td>
#       <td>46.3</td>
#       <td>-4.3</td>
#       <td>34</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2022-01-02</td>
#       <td>28914</td>
#       <td>57.9</td>
#       <td>-1.3</td>
#       <td>42</td>
#     </tr>
# ...

# %%
Question(question_8613)
# Out:
#  <h2 style = "background-color:yellow; ">Description</h2>
# <h3 = "white-space: pre-wrap;">data=pd.read_csv("/content/PAAinJN/csv_file/bike_seoul.csv")</h3>
# <p>1. Excludes column 'day'.</p>
# <p>2. Normalize each value and store it in df.</p>
# <p>(value -mean) / (std)</p>
# <HR>
# <div style = "float:left;width:50%">
# <h2> Data before preprocessing </h2>
# <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>day</th>
#       <th>rent</th>
#       <th>humidity</th>
#       <th>temperature</th>
#       <th>dust</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2022-01-01</td>
#       <td>29185</td>
#       <td>46.3</td>
#       <td>-4.3</td>
#       <td>34</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2022-01-02</td>
#       <td>28914</td>
#       <td>57.9</td>
#       <td>-1.3</td>
#       <td>42</td>
#     </tr>
#     <tr>
#       <th>2</th>
# ...

# %%
Question(question_8614)
# Out:
#  <h2 style = "background-color:yellow; ">Description</h2>
# <h3 = "white-space: pre-wrap;">data=pd.read_csv("/content/PAAinJN/csv_file/bike_seoul.csv")</h3>
# <p>Let's save a value with a 'rent' value greater than 180000 in df.</p>
# <HR>
# <div style = "float:left;width:50%">
# <h2> Data before preprocessing </h2>
# <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>day</th>
#       <th>rent</th>
#       <th>humidity</th>
#       <th>temperature</th>
#       <th>dust</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2022-01-01</td>
#       <td>29185</td>
#       <td>46.3</td>
#       <td>-4.3</td>
#       <td>34</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2022-01-02</td>
#       <td>28914</td>
#       <td>57.9</td>
#       <td>-1.3</td>
#       <td>42</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2022-01-03</td>
#       <td>53573</td>
# ...

# %%
Question(question_8615)
# Out:
#  <h2 style = "background-color:yellow; ">Description</h2>
# <h3 = "white-space: pre-wrap;">data=pd.read_csv("/content/PAAinJN/csv_file/checkup.csv")</h3>
# <p>Let's save the value with '성별' as '남' in df.</p>
# <HR>
# <div style = "float:left;width:50%">
# <h2> Data before preprocessing </h2>
# <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>나이</th>
#       <th>성별</th>
#       <th>키(cm)</th>
#       <th>몸무게(kg)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>6세</td>
#       <td>남</td>
#       <td>120.5</td>
#       <td>24.2</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>6세</td>
#       <td>여</td>
#       <td>119.3</td>
#       <td>22.9</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>7세</td>
#       <td>남</td>
#       <td>125.7</td>
#       <td>27.1</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>7세</td>
#       <td>여</td>
#       <td>124.5</td>
# ...

# %%
Question(question_8616)
# Out:
#  <h2 style = "background-color:yellow; ">Description</h2>
# <h3 = "white-space: pre-wrap;">data=pd.read_csv("/content/PAAinJN/csv_file/missing_data.csv")</h3>
# <p>Let's fill in the missing values in the data with the average of column D and save it to df.</p>
# <HR>
# <div style = "float:left;width:50%">
# <h2> Data before preprocessing </h2>
# <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#       <th>E</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>1</td>
#       <td>1</td>
#       <td>NaN</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>2</td>
#       <td>2</td>
#       <td>3.0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>3</td>
#       <td>-6</td>
#       <td>2.0</td>
#       <td>2</td>
# ...

# %%
Question(question_8617)
# Out:
#  <h2 style = "background-color:yellow; ">Description</h2>
# <h3 = "white-space: pre-wrap;">data=pd.read_csv("/content/PAAinJN/csv_file/missing_data.csv")</h3>
# <p>Let's remove the missing value and save it to df.</p>
# <HR>
# <div style = "float:left;width:50%">
# <h2> Data before preprocessing </h2>
# <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#       <th>E</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>1</td>
#       <td>1</td>
#       <td>NaN</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>2</td>
#       <td>2</td>
#       <td>3.0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>3</td>
#       <td>-6</td>
#       <td>2.0</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>3</th>
# ...

# %%
Question(question_8618)
# Out:
#  <h2 style = "background-color:yellow; ">Description</h2>
# <h3 = "white-space: pre-wrap;">data1=pd.read_csv("/content/PAAinJN/csv_file/bike_seoul_1to6.csv")</h3>
# <h3 = "white-space: pre-wrap;">data2=pd.read_csv("/content/PAAinJN/csv_file/bike_seoul_7to12.csv")</h3>
# <p>Let's combine data from January to June and data from July to December into one data frame and store it in df.</p>
# <HR>
# <div style = "float:left;width:50%">
# <h2> Data before preprocessing </h2>
# <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>day</th>
#       <th>rent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2023-01-01</td>
#       <td>38,037</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2023-01-02</td>
#       <td>56,609</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>179</th>
#       <td>2023-06-29</td>
# ...

# %%
Question(question_8619)
# Out:
#  <h2 style = "background-color:yellow; ">Description</h2>
# <h3 = "white-space: pre-wrap;">data1=pd.read_csv("/content/PAAinJN/csv_file/merge1.csv")</h3>
# <h3 = "white-space: pre-wrap;">data2=pd.read_csv("/content/PAAinJN/csv_file/merge2.csv")</h3>
# <p>Let's combine data1 and data2 around key1 and key2 and store them in df.</p>
# <HR>
# <div style = "float:left;width:50%">
# <h2> Data before preprocessing </h2>
# <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>key1</th>
#       <th>key2</th>
#       <th>A</th>
#       <th>B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>K0</td>
#       <td>K0</td>
#       <td>A0</td>
#       <td>B0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>K0</td>
#       <td>K1</td>
#       <td>A1</td>
#       <td>B1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>K1</td>
#       <td>K0</td>
#       <td>A2</td>
# ...

# %%
Question(question_8620)
# Out:
#  <h2 style = "background-color:yellow; ">Description</h2>
# <h3 = "white-space: pre-wrap;">data=pd.read_csv("/content/PAAinJN/csv_file/multiindex.pkl")</h3>
# <p>Let's stack the data and store it in the df.</p>
# <HR>
# <div style = "float:left;width:50%">
# <h2> Data before preprocessing </h2>
# <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#     <tr>
#       <th>first</th>
#       <th>second</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">bar</th>
#       <th>one</th>
#       <td>3.130734</td>
#       <td>-0.542424</td>
#       <td>0.548739</td>
#       <td>-1.224236</td>
#     </tr>
#     <tr>
#       <th>two</th>
#       <td>0.532126</td>
#       <td>0.502638</td>
#       <td>-0.948431</td>
# ...

# %%
Question(question_8621)
# Out:
#  <h2 style = "background-color:yellow; ">Description</h2>
# <h3 = "white-space: pre-wrap;">data=pd.read_csv("/content/PAAinJN/csv_file/pivot_table.csv")</h3>
# <p>1. Let's make a pivot table of data and store it in df.</p>
# <p>2. Index columns 'A' and 'B'.</p>
# <p>3. Column 'C' as column.</p>
# <p>4. Let 'D' column be value.</p>
# <HR>
# <div style = "float:left;width:50%">
# <h2> Data before preprocessing </h2>
# <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#       <th>E</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>one</td>
#       <td>A</td>
#       <td>foo</td>
#       <td>1</td>
#       <td>54</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>one</td>
#       <td>B</td>
#       <td>foo</td>
#       <td>23</td>
#       <td>21</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>two</td>
# ...
